# %% [markdown]
# # Example of Async Federated Learning

# %%
# from asyncfl import client
# import torch
import asyncfl as AFL
import pprint

# %%
# print(AFL.__dict_)
s = AFL.Server()
s.create_clients(2)
s.run()
# Out:
# Hello server
# [[0, 1], [1, 1]]
# [<asyncfl.client.Client object at 0x7fc438696310>, <asyncfl.client.Client object at 0x7fc438696400>]
# Running
